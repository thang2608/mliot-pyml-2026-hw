# %% [markdown]
# # Bài 1: Logistic Regression

# %% [markdown]
# ## 1. Import thư viện

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, RobustScaler, StandardScaler

# %% [markdown]
# ## 2. Đọc dữ liệu

# %%
df_train = pd.read_csv('titanic_dataset/titanic_train_processed.csv')
df_val = pd.read_csv('titanic_dataset/titanic_val_processed.csv')
df_test = pd.read_csv('titanic_dataset/titanic_test_processed.csv')
